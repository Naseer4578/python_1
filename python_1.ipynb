# %% [markdown]
# <a href="https://colab.research.google.com/github/Naseer4578/python_1/blob/main/python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print(2+9)
# Out:
# 11

# %%
a=8
print(type(a))
# Out:
# <class 'int'>

# %%
b=2.6
print(type(b))
# Out:
# <class 'float'>

# %%
s='hello'
print(type(s))
# Out:
# <class 'str'>

# %%
a=input()
# Out:
# 2

# %%
a
# Out:
# '2'

# %%
a=int(input())
# Out:
# 2

# %%
a=float(input())
# Out:
# 2.5

# %%
a=input("enter a number:")
# Out:
# enter a number:2

# %%
a=2
b=6
print(a+b)
# Out:
# 8

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# enter a number5
# enter a number2
# 7
# 3
# 10
# 2.5
